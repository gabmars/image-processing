# %%
import skimage
from skimage.io import imread,imshow
from skimage.morphology import binary_erosion,binary_dilation,binary_closing,binary_opening
from skimage.morphology import erosion,dilation,closing,opening,label
from skimage.morphology import rectangle,disk,star,diamond,square
from skimage.color import rgb2gray
import numpy as np
from skimage import img_as_float, img_as_ubyte

# %%
img=imread('1.png')
img=rgb2gray(img)
img=np.clip(img, 0,1).astype(np.bool)

# %%
img.shape
# Out:
# (192, 293)

# %%
imshow(img)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(binary_erosion(img))
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(binary_dilation(img))
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(binary_closing(img))
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(binary_opening(img))
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img1=imread('1.png')
img1=rgb2gray(img1)
img1=np.clip(img1, 0,1).astype(np.bool)

# %%
nimg1=binary_dilation(binary_erosion(img1,disk(3)))
pimg1=binary_erosion(nimg1)
imshow(nimg1^pimg1)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img2=imread('2.png')
img2=rgb2gray(img2)
img2=np.clip(img2, 0,1).astype(np.bool)

# %%
nimg2=binary_dilation(binary_erosion(img2, disk(2)))
pimg2=binary_erosion(nimg2)
imshow(nimg2^pimg2)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img3=imread('3.png')
img3=rgb2gray(img3)
img3=np.clip(img3, 0,1).astype(np.bool)

# %%
nimg3=binary_dilation(binary_erosion(img3, disk(2)))
pimg3=binary_erosion(nimg3)
imshow(nimg3^pimg3)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img4=imread('4.png')
img4=rgb2gray(img4)
img4=np.clip(img4, 0,1).astype(np.bool)
imshow(img4)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg4=binary_dilation(binary_erosion(img4,disk(3)),disk(9))
imshow(nimg4)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img5=imread('5.png')
img5=rgb2gray(img5)
img5=np.clip(img5, 0,1).astype(np.bool)
imshow(img5)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg5=binary_dilation(binary_erosion(img5,disk(3)),star(7))
imshow(nimg5)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img6=imread('6.jpg')
img6=rgb2gray(img6)
# img6=np.clip(img6, 0,1).astype(np.bool)
imshow(img6)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg6=dilation(erosion(img6,disk(3)),disk(2))
imshow(nimg6)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img7=imread('7.png')
img7=rgb2gray(img7)
imshow(img7)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img7=img7[120:200,150:460]

# %%
imshow(img7)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg7=dilation(erosion(img7,diamond(2)),diamond(4))
imshow(nimg7)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img8=imread('8.png')
img8=rgb2gray(img8)
img8=np.clip(img8, 0,1).astype(np.bool)
imshow(img8)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg8=binary_dilation(binary_erosion(img8,square(1)), square(2))
imshow(nimg8)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img9=imread('9.png')
img9=rgb2gray(img9)
# img9=np.clip(img9, 0,1).astype(np.bool)
imshow(img9)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img9=img9[10:40,10:120]

# %%
imshow(img9)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg9=dilation(erosion(img9,square(2)), square(3))
imshow(nimg9)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img10=imread('10.png')
img10=rgb2gray(img10)
# img10=np.clip(img10, 0,1).astype(np.bool)
imshow(img10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
img10=img10[105:165,20:200]

# %%
imshow(img10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimg10=dilation(erosion(img10,square(2)), square(3))
imshow(nimg10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imgj10=imread('10.jpg')
imgj10=rgb2gray(imgj10)
# imgj10=np.clip(imgj10, 0,1).astype(np.bool)
imshow(imgj10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imgj10=imgj10[20:900,200:1000]

# %%
imgj10=imgj10[10:400,380:460]

# %%
imshow(imgj10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# nimgj10=dilation(erosion(imgj10,disk(4)))
nimgj10=erosion(imgj10,disk(5))
imshow(nimgj10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage import img_as_ubyte
import matplotlib.pyplot as plt
from skimage import data
from skimage.filters import threshold_otsu, threshold_adaptive
import cv2


image = imgj10

global_thresh = threshold_otsu(image)
binary_global = image > global_thresh

block_size = 3
binary_adaptive = threshold_adaptive(image, block_size, offset=10)

fig, axes = plt.subplots(nrows=3, figsize=(7, 8))
ax0, ax1, ax2 = axes
plt.gray()

ax0.imshow(image)
ax0.set_title('Image')

ax1.imshow(binary_global)
ax1.set_title('Global thresholding')

ax2.imshow(binary_adaptive)
ax2.set_title('Adaptive thresholding')

for ax in axes:
    ax.axis('off')

plt.show()
img = img_as_ubyte(binary_global)
imshow(img)
# Out:
# D:\Anaconda\lib\site-packages\skimage\filters\thresholding.py:222: skimage_deprecation: Function ``threshold_adaptive`` is deprecated and will be removed in version 0.15. Use ``threshold_local`` instead.
#   def threshold_adaptive(image, block_size, method='gaussian', offset=0,
# D:\Anaconda\lib\site-packages\skimage\filters\thresholding.py:224: UserWarning: The return value of `threshold_local` is a threshold image, while `threshold_adaptive` returned the *thresholded* image.
#   warn('The return value of `threshold_local` is a threshold image, while '
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.filters.rank import otsu
from skimage.filters import threshold_otsu

p8 = imgj10

radius = 100
selem = disk(radius)

# t_loc_otsu is an image
t_loc_otsu = otsu(p8, selem)
loc_otsu = p8 >= t_loc_otsu

# t_glob_otsu is a scalar
t_glob_otsu = threshold_otsu(p8)
glob_otsu = p8 >= t_glob_otsu

imshow(glob_otsu)
# Out:
# D:\Anaconda\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.filters import rank

radius = 6
t = rank.otsu(imgj10, disk(radius))

imshow(t)
# Out:
# D:\Anaconda\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import matplotlib
import matplotlib.pyplot as plt

from skimage.data import page
from skimage.filters import (threshold_otsu, threshold_niblack,
                             threshold_sauvola)


matplotlib.rcParams['font.size'] = 9


image = imgj10
binary_global = image > threshold_otsu(image)

window_size = 25
thresh_niblack = threshold_niblack(image, window_size=window_size, k=0.8)
thresh_sauvola = threshold_sauvola(image, window_size=window_size)

binary_niblack = image > thresh_niblack
binary_sauvola = image > thresh_sauvola

# %%
imshow(binary_niblack)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
nimgj10=dilation(erosion(~binary_niblack))

imshow(nimgj10^erosion(nimgj10))
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imshow(binary_sauvola)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.filters import threshold_mean


image = imgj10
print(image)
thresh = threshold_mean(image)
print(thresh)
binary = image > thresh


imshow(binary)
# Out:
# [[0.09451765 0.10679529 0.09021529 ... 0.06200627 0.09503059 0.41319059]
#  [0.06592784 0.11239843 0.12215333 ... 0.0225     0.07169373 0.24389255]
#  [0.33934431 0.25745882 0.10724    ... 0.01538863 0.01333333 0.08409137]
#  ...
#  [0.55967765 0.49130667 0.47168392 ... 0.50307137 0.55324118 0.57677059]
#  [0.59919098 0.50085412 0.47954196 ... 0.54088824 0.59048471 0.55126902]
#  [0.49862902 0.48938706 0.51932314 ... 0.47422157 0.51989647 0.54228706]]
# 0.5113622449597788
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
from skimage.filters import roberts, sobel, scharr, prewitt

# %%
edge_scharr = roberts(imgj10)

imshow(edge_scharr)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage.morphology import watershed
from skimage.feature import peak_local_max

# %%
bimgj10=np.clip(rgb2gray(imgj10), 0,1).astype(np.bool)

distance = ndi.distance_transform_edt(bimgj10)
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)),
                            labels=bimgj10)
markers = ndi.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=bimgj10)

imshow(labels, cmap=plt.cm.nipy_spectral, interpolation='nearest')
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
imgj10=imread('10.jpg')
imgj10=rgb2gray(imgj10)
imgj10=imgj10[20:900,200:1000]
plt.figure(figsize=(20,20))
imgj10[10:400,380:460] = img_as_float(binary_sauvola)
imshow(imgj10)
# Out:
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
